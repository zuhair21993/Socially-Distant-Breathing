# %% [markdown]
# # Importing Dependancies

# %%
# %matplotlib notebook 
# %matplotlib inline

import os
import csv
import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import zipfile
from scipy.stats import linregress
import glob

# %% [markdown]
# # Reading Files & Creating DataFrames

# %%
#Air Quality Index DataFrame
aqi_df = pd.read_csv("../Output/aqi_compiled.csv")

# %% [markdown]
# # Analysis & Workings

# %%
aqi_df
# Out:
#          State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0      Alabama     Autauga  1980            179        122             35
# 1      Alabama     Colbert  1980            274        127             45
# 2      Alabama     Jackson  1980            366         85            110
# 3      Alabama   Jefferson  1980            343        171            109
# 4      Alabama  Lauderdale  1980            274        120             58
# ...        ...         ...   ...            ...        ...            ...
# 38474  Wyoming    Sublette  2019            210        127             72
# 38475  Wyoming  Sweetwater  2019            273        210             60
# 38476  Wyoming       Teton  2019            244        209             35
# 38477  Wyoming       Uinta  2019            181        146             34
# 38478  Wyoming      Weston  2019            181        161             20
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# ...

# %%
NY_df = aqi_df.loc[aqi_df["State"] == "New York"]

# %%
NY_df
# Out:
#           State       County  Year  Days with AQI  Good Days  Moderate Days  \
# 349    New York       Albany  1980            175         47             74
# 350    New York        Bronx  1980            350        176            122
# 351    New York       Broome  1980            365        218            118
# 352    New York   Chautauqua  1980            338        130            101
# 353    New York      Chemung  1980            359        291             53
# ...         ...          ...   ...            ...        ...            ...
# 38044  New York      Steuben  2019            274        263             11
# 38045  New York      Suffolk  2019            273        215             49
# 38046  New York     Tompkins  2019            242        236              6
# 38047  New York        Wayne  2019            208        193             15
# 38048  New York  Westchester  2019            273        240             32
#
# ...

# %%
NY_1980_df = NY_df.loc[NY_df["Year"] == 1980]

# %%
NY_1980_df
# Out:
#         State        County  Year  Days with AQI  Good Days  Moderate Days  \
# 349  New York        Albany  1980            175         47             74
# 350  New York         Bronx  1980            350        176            122
# 351  New York        Broome  1980            365        218            118
# 352  New York    Chautauqua  1980            338        130            101
# 353  New York       Chemung  1980            359        291             53
# 354  New York      Dutchess  1980            361        244             80
# 355  New York          Erie  1980            365         15             97
# 356  New York         Essex  1980            332        227             57
# 357  New York         Kings  1980            358         86            172
# 358  New York        Monroe  1980            365         35            119
# 359  New York        Nassau  1980            366        140            158
# ...

# %%
NewYork_df = NY_1980_df.drop(['Days CO', 'Days NO2', 'Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10'], axis=1)

# %%
NewYork_df["Bad Days"] = NewYork_df["Unhealthy for Sensitive Groups Days"] + NewYork_df["Unhealthy Days"] + NewYork_df["Very Unhealthy Days"] + NewYork_df["Hazardous Days"]

# %%
NewYork_df["Max_AQI"] = NewYork_df["Max AQI"]

# %%
NewYork_df["90th_Percentile_AQI"] = NewYork_df["90th Percentile AQI"]

# %%
NewYork_df["Median_AQI"] = NewYork_df["Median AQI"]

# %%
NewYork_df
# Out:
#         State        County  Year  Days with AQI  Good Days  Moderate Days  \
# 349  New York        Albany  1980            175         47             74
# 350  New York         Bronx  1980            350        176            122
# 351  New York        Broome  1980            365        218            118
# 352  New York    Chautauqua  1980            338        130            101
# 353  New York       Chemung  1980            359        291             53
# 354  New York      Dutchess  1980            361        244             80
# 355  New York          Erie  1980            365         15             97
# 356  New York         Essex  1980            332        227             57
# 357  New York         Kings  1980            358         86            172
# 358  New York        Monroe  1980            365         35            119
# 359  New York        Nassau  1980            366        140            158
# ...

# %%
NewYork_1980_df = NewYork_df.drop(['Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI', '90th Percentile AQI', 'Median AQI'], axis=1)

# %%
NewYork_1980_df["% Good Days"]=NewYork_1980_df["Good Days"]/NewYork_1980_df["Days with AQI"]*100

# %%
NewYork_1980_df["% Moderate Days"]=NewYork_1980_df["Moderate Days"]/NewYork_1980_df["Days with AQI"]*100

# %%
NewYork_1980_df["% Bad Days"]=NewYork_1980_df["Bad Days"]/NewYork_1980_df["Days with AQI"]*100

# %%
NewYork_1980_df
# Out:
#         State        County  Year  Days with AQI  Good Days  Moderate Days  \
# 349  New York        Albany  1980            175         47             74
# 350  New York         Bronx  1980            350        176            122
# 351  New York        Broome  1980            365        218            118
# 352  New York    Chautauqua  1980            338        130            101
# 353  New York       Chemung  1980            359        291             53
# 354  New York      Dutchess  1980            361        244             80
# 355  New York          Erie  1980            365         15             97
# 356  New York         Essex  1980            332        227             57
# 357  New York         Kings  1980            358         86            172
# 358  New York        Monroe  1980            365         35            119
# 359  New York        Nassau  1980            366        140            158
# ...

# %%
NJ_df = aqi_df.loc[aqi_df["State"] == "New Jersey"]

# %%
NJ_1980_df = NJ_df.loc[NJ_df["Year"] == 1980]

# %%
NewJersey_df = NJ_1980_df.drop(['Days CO', 'Days NO2', 'Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10'], axis=1)

# %%
NewJersey_df["Bad Days"] = NewJersey_df["Unhealthy for Sensitive Groups Days"] + NewJersey_df["Unhealthy Days"] + NewJersey_df["Very Unhealthy Days"] + NewJersey_df["Hazardous Days"]

# %%
NewJersey_df["Max_AQI"] = NewJersey_df["Max AQI"]

# %%
NewJersey_df["90th_Percentile_AQI"] = NewJersey_df["90th Percentile AQI"]

# %%
NewJersey_df["Median_AQI"] = NewJersey_df["Median AQI"]

# %%
NewJersey_1980_df = NewJersey_df.drop(['Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI', '90th Percentile AQI', 'Median AQI'], axis=1)

# %%
NewJersey_1980_df["% Good Days"]=NewJersey_1980_df["Good Days"]/NewJersey_1980_df["Days with AQI"]*100

# %%
NewJersey_1980_df["% Moderate Days"]=NewJersey_1980_df["Moderate Days"]/NewJersey_1980_df["Days with AQI"]*100

# %%
NewJersey_1980_df["% Bad Days"]=NewJersey_1980_df["Bad Days"]/NewJersey_1980_df["Days with AQI"]*100

# %%
NewJersey_1980_df
# Out:
#           State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 323  New Jersey    Atlantic  1980            328        115            139
# 324  New Jersey      Bergen  1980            323        145            123
# 325  New Jersey  Burlington  1980            325        110            113
# 326  New Jersey      Camden  1980            341        125            113
# 327  New Jersey    Cape May  1980            233        142             39
# 328  New Jersey  Cumberland  1980            287        148             91
# 329  New Jersey       Essex  1980            351        123            160
# 330  New Jersey  Gloucester  1980             49         12             23
# 331  New Jersey      Hudson  1980            317        104            153
# 332  New Jersey   Hunterdon  1980            215        109             35
# 333  New Jersey      Mercer  1980            308        175             57
# ...

# %%
CT_df = aqi_df.loc[aqi_df["State"] == "Connecticut"]

# %%
CT_1980_df = CT_df.loc[CT_df["Year"] == 1980]

# %%
Connecticut_df = CT_1980_df.drop(['Days CO', 'Days NO2', 'Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10'], axis=1)

# %%
Connecticut_df["Bad Days"] = Connecticut_df["Unhealthy for Sensitive Groups Days"] + Connecticut_df["Unhealthy Days"] + Connecticut_df["Very Unhealthy Days"] + Connecticut_df["Hazardous Days"]

# %%
Connecticut_df["Max_AQI"] = Connecticut_df["Max AQI"]

# %%
Connecticut_df["90th_Percentile_AQI"] = Connecticut_df["90th Percentile AQI"]

# %%
Connecticut_df["Median_AQI"] = Connecticut_df["Median AQI"]

# %%
Conn_1980_df = Connecticut_df.drop(['Unhealthy for Sensitive Groups Days', 'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI', '90th Percentile AQI', 'Median AQI'], axis=1)

# %%
Conn_1980_df["% Good Days"] = Conn_1980_df["Good Days"]/Conn_1980_df["Days with AQI"]*100

# %%
Conn_1980_df["% Moderate Days"] = Conn_1980_df["Moderate Days"]/Conn_1980_df["Days with AQI"]*100

# %%
Conn_1980_df["% Bad Days"] = Conn_1980_df["Bad Days"]/Conn_1980_df["Days with AQI"]*100

# %%
Conn_1980_df
# Out:
#           State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 76  Connecticut   Fairfield  1980            366         35            104
# 77  Connecticut    Hartford  1980            366        115            193
# 78  Connecticut  Litchfield  1980            164         95             26
# 79  Connecticut   Middlesex  1980            164         69             38
# 80  Connecticut   New Haven  1980            366        157            134
# 81  Connecticut     Tolland  1980            148         72             27
#
#     Bad Days  Max_AQI  90th_Percentile_AQI  Median_AQI  % Good Days  \
# 76       227      289                  219         120     9.562842
# 77        58      260                  126          60    31.420765
# 78        43      269                  182          44    57.926829
# 79        57      267                  218          67    42.073171
# 80        75      295                  150          59    42.896175
# ...
